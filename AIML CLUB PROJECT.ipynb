# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt # visualizing data
# %matplotlib inline 
import seaborn as sns

# %%
data=pd.read_csv(r"C:\Users\Predator\Documents\list\Project List.csv")

# %%
data
# Out:
#                   Name  Age  Gender  Hours_Studied   IQ  Physics_Marks  \
# 0          Derek Smith   26  Female       6.596347   98             68
# 1    Christopher Boyle   37    Male       5.672202  133             44
# 2        Bradley Jones   19    Male       6.282581   89             90
# 3        Eric Martinez   21    Male       8.004422  106             81
# 4     Jennifer Ferrell   29  Female       4.322501   88             41
# ..                 ...  ...     ...            ...  ...            ...
# 995      Jonathan Long   29  Female       4.525427  100             64
# 996     Michael Morgan   34  Female       9.049785  129             70
# 997   Jacob Cunningham   29    Male       5.942553  108             68
# 998  Brittany Matthews   39  Female       5.268965  120             73
# 999      Daniel Kramer   28  Female       9.840650  106             74
#
#      Math_Marks  Chemistry_Marks  Has_Part_Time_Job Age Group
# ...

# %%
data.shape
# Out:
# (1000, 10)

# %%
data.dtypes
# Out:
# Name                  object
# Age                    int64
# Gender                object
# Hours_Studied        float64
# IQ                     int64
# Physics_Marks          int64
# Math_Marks             int64
# Chemistry_Marks        int64
# Has_Part_Time_Job       bool
# Age Group             object
# dtype: object

# %%
data['Gender']. value_counts()
# Out:
# Gender
# Female    516
# Male      484
# Name: count, dtype: int64

# %%
data['Age Group'].value_counts()
# Out:
# Age Group
# 20 to 29    386
# 30 to 39    330
# 40 to 49    215
# 10 to 19     69
# Name: count, dtype: int64

# %%
data['Has_Part_Time_Job'].value_counts()
# Out:
# Has_Part_Time_Job
# True     504
# False    496
# Name: count, dtype: int64

# %%
data['total'] = data['Physics_Marks'] + data['Chemistry_Marks'] + data['Math_Marks']

# %%
data['average'] = data['total']/ 3

# %%
sns.distplot(data['Math_Marks'])
# Out:
# C:\Users\Predator\AppData\Local\Temp\ipykernel_30064\2032492924.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Math_Marks'])
# <Axes: xlabel='Math_Marks', ylabel='Density'>

# %%
sns.distplot(data['Chemistry_Marks'])
# Out:
# C:\Users\Predator\AppData\Local\Temp\ipykernel_30064\918933621.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Chemistry_Marks'])
# <Axes: xlabel='Chemistry_Marks', ylabel='Density'>

# %%
sns.distplot(data['Physics_Marks'])
# Out:
# C:\Users\Predator\AppData\Local\Temp\ipykernel_30064\4274518769.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Physics_Marks'])
# <Axes: xlabel='Physics_Marks', ylabel='Density'>

# %%
sns.distplot(data['average'])
# Out:
# C:\Users\Predator\AppData\Local\Temp\ipykernel_30064\2765520033.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['average'])
# <Axes: xlabel='average', ylabel='Density'>

# %%
sns.pairplot(data)
# Out:
# <__array_function__ internals>:200: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# C:\Users\Predator\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 sns.barplot(data['Age Group'],data['Has_Part_Time_Job'])
#
# TypeError: barplot() takes from 0 to 1 positional arguments but 2 were given

# %%
sns.barplot(x=data['Age Group'] , y=data['average'] , alpha=0.5)
# Out:
# <Axes: xlabel='Age Group', ylabel='average'>

# %%
sns.barplot(x=data['Gender'] , y=data['average'] , alpha=0.5)
# Out:
# <Axes: xlabel='Gender', ylabel='average'>

# %%
sns.barplot(x=data['Has_Part_Time_Job'] , y=data['average'] , alpha=0.5)
# Out:
# <Axes: xlabel='Has_Part_Time_Job', ylabel='average'>

# %%
data['Math_PassStatus'] = np.where(data['Math_Marks'] < 50 , 'F' , 'P'  )

# %%
data['Physics_PassStatus'] = np.where(data['Physics_Marks'] < 50 , 'F' , 'P')

# %%
data['Chemistry_PassStatus'] = np.where(data['Chemistry_Marks'] < 50 , 'F' , 'P')

# %%
data.head()
# Out:
#                 Name  Age  Gender  Hours_Studied   IQ  Physics_Marks  \
# 0        Derek Smith   26  Female       6.596347   98             68
# 1  Christopher Boyle   37    Male       5.672202  133             44
# 2      Bradley Jones   19    Male       6.282581   89             90
# 3      Eric Martinez   21    Male       8.004422  106             81
# 4   Jennifer Ferrell   29  Female       4.322501   88             41
#
#    Math_Marks  Chemistry_Marks  Has_Part_Time_Job Age Group  total    average  \
# 0         100               43               True  20 to 29    211  70.333333
# 1          53               92               True  30 to 39    189  63.000000
# 2          48               57               True  10 to 19    195  65.000000
# 3          88               41              False  20 to 29    210  70.000000
# 4          83               85               True  20 to 29    209  69.666667
#
#   Physics_PassStatus Chemistry_PassStatus math_passStatus Math_passStatus  \
# ...

# %%
data['Math_passStatus'].value_counts()
# Out:
# Math_passStatus
# P    846
# F    154
# Name: count, dtype: int64

# %%
data['Physics_PassStatus'].value_counts()
# Out:
# Physics_PassStatus
# P    834
# F    166
# Name: count, dtype: int64

# %%
data['Chemistry_PassStatus'].value_counts()
# Out:
# Chemistry_PassStatus
# P    863
# F    137
# Name: count, dtype: int64

# %%
p = sns.countplot(x = 'Age Group',data=data , hue='Math_passStatus' , palette = 'bright')

# %%
p = sns.countplot(x = 'Has_Part_Time_Job',data=data , hue='Math_passStatus' , palette = 'bright')

# %%
p = sns.countplot(x = 'Gender',data=data , hue='Math_passStatus' , palette = 'bright')

# %%
p = sns.countplot(x = 'Age Group',data=data , hue='Physics_PassStatus' , palette = 'bright')

# %%
p = sns.countplot(x = 'Gender',data=data , hue='Physics_PassStatus' , palette = 'bright')

# %%
p = sns.countplot(x = 'Has_Part_Time_Job',data=data , hue='Physics_PassStatus' , palette = 'bright')

# %%
p = sns.countplot(x = 'Age Group',data=data , hue='Chemistry_PassStatus' , palette = 'bright')

# %%
p = sns.countplot(x = 'Gender',data=data , hue='Chemistry_PassStatus' , palette = 'bright')

# %%
p = sns.countplot(x = 'Has_Part_Time_Job',data=data , hue='Chemistry_PassStatus' , palette = 'bright')
